# %%
import pandas as pd

# %%
path = "data/health.csv"
df=pd.read_csv(path)

# %%
df
# Out:
#                                             slug_name  \
# 0   department_of_health_&_family_welfare_(includi...
# 1                       department_of_health_research
# 2           total_ministry_of_health_&_family_welfare
# 3                                   ministry_of_ayush
# 4                       national_health_mission_(nhm)
# 5     pradhan_mantri_swasthya_suraksha_yojana_(pmssy)
# 6                   national_health_protection_scheme
# 7                                 jan_aushadhi_scheme
# 8                   total_expenditure_(rs._in_crore)_
# 9         gdp_at_current_market_prices_(rs._in_crore)
# 10        total_mohfw_as_percent_of_total_expenditure
# 11                        total_nhm_as_percent_of_gdp
# 12        total_mohfw_as_percent_of_gdp_(excl._ayush)
# 13        total_nhm_as_percent_of_mohfw_(incl._ayush)
# 14        total_mohfw_as_percent_of_gdp_(incl._ayush)
#
#                                            index_name     2012-13  \
# 0   Department of Health & Family Welfare (includi...    26449.00
# 1                       Department of Health Research      720.00
# 2           Total Ministry of Health & Family Welfare    27169.00
# 3                                   Ministry of AYUSH      715.00
# 4                       National Health Mission (NHM)    18046.70
# 5     Pradhan Mantri Swasthya Suraksha Yojana (PMSSY)      989.00
# 6                   National Health Protection Scheme     1001.70
# 7                                 Jan Aushadhi Scheme        1.70
# 8                   Total Expenditure (Rs. In Crore)   1410372.00
# 9         GDP at Current Market Prices (Rs. In Crore)  9946636.00
# 10        Total MoHFW as percent of Total Expenditure        1.90
# 11                        Total NHM as percent of GDP        0.18
# 12        Total MoHFW as percent of GDP (excl. AYUSH)        0.27
# 13        Total NHM as percent of MoHFW (incl. AYUSH)       65.00
# 14        Total MoHFW as percent of GDP (incl. AYUSH)        0.28
#
#         2013-14   2014-15      2015-16  2016-17 (BE)  2016-17 (RE)  \
# 0      28618.40   30626.4     33121.40      37061.50      38343.30
# 1        874.10     910.8       992.80       1144.80       1344.80
# 2      29492.50   31537.2     34114.20      38206.30      39688.10
# 3        642.40     616.8      1075.30       1326.20       1307.40
# 4      18633.80   19751.4     20213.20      20762.00      22597.95
# 5       1273.20       822      1577.85       2450.00       1953.24
# 6        887.50     550.6          NaN       1500.00        724.00
# 7         15.20         -        16.91         35.00         49.75
# 8    1559447.00   1663673   1790783.00    1978060.00    2014407.00
# 9   11236635.00  12433749  13675331.00   15075429.00   15075429.00
# 10         1.90       1.9         1.90          1.90          2.00
# 11         0.17      0.16         0.15          0.14          0.15
# 12         0.26      0.25         0.25          0.25          0.26
# 13        62.00        61        57.00         53.00         55.00
# 14         0.27      0.26         0.26          0.26          0.27
#
#     2017-18 (BE)           unit    color
# 0       47352.50       Rs crore  #142426
# 1        1500.00       Rs crore  #142427
# 2       48852.50       Rs crore  #142428
# 3        1428.65       Rs crore  #142429
# 4       27131.20       Rs crore  #142430
# 5        3975.00       Rs crore  #142431
# 6        1000.00       Rs crore  #142432
# 7          74.62       Rs crore  #142433
# 8     2146735.00       Rs crore  #142434
# 9    16847455.00       Rs crore  #142435
# 10          2.30  Percentage(%)  #142436
# 11          0.16  Percentage(%)  #142437
# 12          0.29  Percentage(%)  #142438
# 13         54.00  Percentage(%)  #142439
# 14          0.30  Percentage(%)  #142440

# %%
file_name= "health"
for index, row in enumerate(df.iterrows()):
    #rint " .. raw:: html\n"
    print '    <iframe src="viz/visualization.html#barchart/'+file_name+'/'+row[1][0] +'" width="100%", height="500",  frameBorder="0"></iframe>\n'
# Out:
#     <iframe src="viz/visualization.html#barchart/agriculture/department_of_agriculture,_cooperation_and_farmers_welfare" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/department_of_animal_husbandry,_dairying_and_fisheries" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/department_of_agricultural_research_and_education" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/total_expenditure_under_moa_with_interest_subvention_(rs._in_crore)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/interest__subvention__for_providing_short_term_credit_to_farmers" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/share_of_expenditure_by_moa_(including_interest_subvention)_in_total_union_government_expenditure_(%)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/share_of_expenditure_by_moa_(including_interest_subvention)_in_gdp_(%)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/pradhan_mantri_fasal_bima_yojana_(pmfby)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/total_allocations_for_pradhan_mantri_krishi_sinchai_yojana__(pmksy)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/rashtriya_krishi_vikas_yojana_(rkvy)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/national_food_security_mission_(nfsm)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/paramparagat_krishi_vikas_yojana_(pkvy)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/national_mission_on_oil_seed_and_oil_palm_(nmoop)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/national_mission_on_horticulture_(nmh)" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/white_revolution" width="100%", height="500",  frameBorder="0"></iframe>
#
#     <iframe src="viz/visualization.html#barchart/agriculture/blue_revolution" width="100%", height="500",  frameBorder="0"></iframe>
