# %%
import pandas as pd

# %%
df=pd.read_csv("data/education.csv")

# %%
df
# Out:
#                                             slug_name  \
# 0               dept_of_school_education_and_literacy
# 1                            dept_of_higher_education
# 2   education_-_education_by_ministry_of_human_res...
# 3        union_govt_spending_on_education_as_%_of_gdp
# 4   union_govt_spending_on_education_as_%_of_union...
# 5                             beti_bachao_beti_padhao
# 6                     nem-sarva_shiksha_abhiyan_(ssa)
# 7       nem-rastriya_madhyamik_shiksha_abhiyan_(rmsa)
# 8       nem-rashtriya_uchchatar_siksha_abhiyan_(rusa)
# 9            nem-teacher_training_and_saakshar_bharat
# 10             national_education_mission_(nem)-total
# 11  scheme_for_providing_education_to_madrasa_and_...
# 12                       kendriya_vidyalaya_sangathan
# 13                       navodaya_vidyalaya_sanghatan
# 14                                 mid_day_meal_(mdm)
# 15  indian_institutes_of_technology_and_indian_ins...
# ...

# %%
file_name= "education"
for index, row in enumerate(df.iterrows()):
    print " .. raw:: html\n"
    print '    <iframe src="https://cbgaindia.github.io/unionbudget17/viz/test_url.html#barchart/'+file_name+'/'+row[1][0] +'" width="100%", height="500",  frameBorder="0"></iframe>\n'
# Out:
#  .. raw:: html
#
#     <iframe src="https://cbgaindia.github.io/unionbudget17/viz/test_url.html#barchart/education/dept_of_school_education_and_literacy" width="100%", height="500",  frameBorder="0"></iframe>
#
#  .. raw:: html
#
#     <iframe src="https://cbgaindia.github.io/unionbudget17/viz/test_url.html#barchart/education/dept_of_higher_education" width="100%", height="500",  frameBorder="0"></iframe>
#
#  .. raw:: html
#
#     <iframe src="https://cbgaindia.github.io/unionbudget17/viz/test_url.html#barchart/education/education_-_education_by_ministry_of_human_resource_development(mhrd)" width="100%", height="500",  frameBorder="0"></iframe>
#
#  .. raw:: html
#
#     <iframe src="https://cbgaindia.github.io/unionbudget17/viz/test_url.html#barchart/education/union_govt_spending_on_education_as_%_of_gdp" width="100%", height="500",  frameBorder="0"></iframe>
#
#  .. raw:: html
#
# ...
